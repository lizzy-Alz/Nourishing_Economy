# %%
from Library import *

# %%
open_json()
# Out:
# {'mipymes': [{'id': 1, 'name': 'Tulipan', 'location': {'latitude': 40.4168, 'longitude': -3.7038, 'address': 'j/malecon'}, 'has_address': True, 'products': [{'id': 'prod_001', 'name': 'Producto Premium', 'price': 25.5, 'origin': 'Madrid', 'brand': 'MyBrand'}, {'id': 'prod_002', 'name': 'Producto BÃ¡sico', 'price': 15.75, 'origin': 'Barcelona', 'brand': 'OtherBrand'}, {'id': 'prod_003', 'name': 'Producto EstÃ¡ndar', 'price': 30.0, 'origin': 'Valencia', 'brand': 'LocalBrand'}]}, {'id': 2, 'name': 'Patron', 'location': {'latitude': 41.3888, 'longitude': 2.1589, 'address': '10 de octubre'}, 'has_address': True, 'products': [{'id': 'prod_004', 'name': 'Producto Artesanal', 'price': 18.9, 'origin': 'Catalonia', 'brand': 'Artisanal'}]}]}

# %%
access()
# Out:
# Tulipan
# Patron

# %%
average()
# Out:
# 22.5375

# %%
name_and_products()
# Out:
# Tulipan
# 3
# Patron
# 1
# ['Producto Premium',
#  'Producto BÃ¡sico',
#  'Producto EstÃ¡ndar',
#  'Producto Artesanal']
